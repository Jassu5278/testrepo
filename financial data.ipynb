# %%
pip install pandas yfinance matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (1.5.3)
# Collecting yfinance
#   Downloading yfinance-0.2.43-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from yfinance) (2.5.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.4-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.6.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ------- -------------------------------- 0.5/3.0 MB 1.3 MB/s eta 0:00:02
#      -------------- ------------------------- 1.0/3.0 MB 1.5 MB/s eta 0:00:02
#      ----------------- ---------------------- 1.3/3.0 MB 1.6 MB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 1.7 MB/s eta 0:00:01
#      ---------------------------- ----------- 2.1/3.0 MB 1.7 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 1.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jaswanth kumar reddy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Downloading yfinance-0.2.43-py2.py3-none-any.whl (84 kB)
# Downloading frozendict-2.4.4-py311-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.6-py3-none-any.whl size=138939 sha256=fe896d1522da16e30ecd8bf2c80a578a1fa12d6094f011d442d3d8cb14b6b1b3
#   Stored in directory: c:\users\jaswanth kumar reddy\appdata\local\pip\cache\wheels\1c\09\7e\9f659fde248ecdc1722a142c1d744271aad3914a0afc191058
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.4.4 html5lib-1.1 multitasking-0.0.11 peewee-3.17.6 yfinance-0.2.43
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# Define the stock symbol and the time period
stock_symbol = 'AAPL'
start_date = '2023-01-01'
end_date = '2023-09-21'

# Download the data
data = yf.download(stock_symbol, start=start_date, end=end_date)

# Display the first few rows of the data
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  123.904633
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.182610
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  123.855095
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  128.412216
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  128.937286
#
#                Volume
# Date
# 2023-01-03  112117500
# 2023-01-04   89113600
# 2023-01-05   80962700
# 2023-01-06   87754700
# 2023-01-09   70790800

# %%
# Plot the closing prices
plt.figure(figsize=(12, 6))
plt.plot(data['Close'], label='Close Price', color='blue')
plt.title(f'{stock_symbol} Closing Prices')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid()
plt.show()
